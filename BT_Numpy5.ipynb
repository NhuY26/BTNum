# %% [markdown]
# <a href="https://colab.research.google.com/github/NhuY26/BTNum/blob/main/BT_Numpy5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import PIL as pt 
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
doc_img = pt.Image.open("/content/anhL.jpg")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#đọc ảnh ra màn hình 
doc_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=402x558 at 0x7FCDEF46B750>

# %%
#Chuyển bức ảnh từ cấu trúc dữ liệu của PIL sang NumPy array 
change_img = np.array(doc_img.getdata())

#Số chiều
print("số chiều", change_img.ndim)

#kích thước
print("kích thước", change_img.shape)
# Out:
# số chiều 2
# kích thước (224316, 3)

# %%
#chuyển ảnh màu sang ảnh xám 
new_img = doc_img.convert("L")
new_img
# Out:
# <PIL.Image.Image image mode=L size=402x558 at 0x7FCDEF3EC050>

# %%
#lưu vào máy
new_img.save("new_totoro.jpg")

#thu nhỏ ảnh
new_width  = 300
new_height = 300
small_img = doc_img.resize((new_width,new_height))
small_img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FCDEF3F9890>

# %%
#Chuyển ảnh màu sang Halftone 
new_img = doc_img.convert("1")
new_img
# Out:
# <PIL.Image.Image image mode=1 size=402x558 at 0x7FCDFDB47F50>

# %%
#làm mờ ảnh 
from PIL import ImageFilter
new_img = doc_img.filter(ImageFilter.GaussianBlur(radius=20))
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=402x558 at 0x7FCDEF46B590>

# %%
#xoay ảnh 
n_img = doc_img.rotate((180))
n_img
# Out:
# <PIL.Image.Image image mode=RGB size=402x558 at 0x7FCDEF3E5950>

# %%
#pytorch 
import torch

# %%
#tensor hạng 1 
ts_1 = torch.tensor([1,2,3,4,5])
print("Tensor hạng 1: ",ts_1)
print("hạng: ",ts_1.ndim)
# Out:
# Tensor hạng 1:  tensor([1, 2, 3, 4, 5])
# hạng:  1

# %%
#tensor hạng 2
ts_2 = torch.rand(2,2)
print("Tensor hạng 2: ")
print(ts_2)
print("hạng : ",ts_2.ndim)
# Out:
# Tensor hạng 2:
# tensor([[0.7546, 0.0572],
#         [0.2930, 0.4839]])
# hạng :  2

# %%
#tensor hạng 3
ts_3 = torch.rand(2,3,5)
print("Tensor hạng 3: ")
print(ts_3)
print("hạng : ",ts_3.ndim)
# Out:
# Tensor hạng 3:
# tensor([[[0.8620, 0.3096, 0.5542, 0.2205, 0.9914],
#          [0.9437, 0.4903, 0.8717, 0.9626, 0.3201],
#          [0.1645, 0.4778, 0.7739, 0.8371, 0.5030]],
#
#         [[0.4528, 0.0954, 0.1393, 0.5283, 0.1448],
#          [0.1606, 0.3542, 0.9061, 0.5680, 0.4125],
#          [0.1003, 0.2481, 0.2875, 0.1976, 0.1616]]])
# hạng :  3

# %%
#tensor hạng 4
ts_4 = torch.rand(1,3,4,6)
print("Tensor hạng 4: ")
print(ts_4)
print("hạng : ",ts_4.ndim)
# Out:
# Tensor hạng 4:
# tensor([[[[0.6725, 0.2048, 0.7496, 0.8142, 0.2410, 0.5856],
#           [0.6924, 0.8382, 0.9901, 0.7537, 0.6464, 0.4927],
#           [0.8325, 0.4585, 0.6716, 0.0113, 0.6155, 0.4488],
#           [0.8918, 0.4839, 0.2400, 0.0237, 0.5899, 0.3649]],
#
#          [[0.7977, 0.6410, 0.0386, 0.7703, 0.1912, 0.1120],
#           [0.5654, 0.4734, 0.8850, 0.5834, 0.3865, 0.4561],
#           [0.0198, 0.1966, 0.8303, 0.2235, 0.8275, 0.9367],
#           [0.1841, 0.5264, 0.3671, 0.4938, 0.1605, 0.5855]],
#
#          [[0.2624, 0.4512, 0.7698, 0.8697, 0.8918, 0.5300],
#           [0.4221, 0.3930, 0.9780, 0.7713, 0.6356, 0.9777],
#           [0.3166, 0.9543, 0.3051, 0.4593, 0.9874, 0.6931],
#           [0.9190, 0.1168, 0.6512, 0.3128, 0.6963, 0.4159]]]])
# hạng :  4
